# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
matches = pd.read_csv("data/matches.csv")
deliveries = pd.read_csv("data/deliveries.csv")

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
matches.shape
# Out:
# (756, 18)

# %%
deliveries.shape
# Out:
# (150460, 21)

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='str')

# %%
deliveries.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='str')

# %%
matches.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    str
#  3   date             756 non-null    str
#  4   team1            756 non-null    str
#  5   team2            756 non-null    str
#  6   toss_winner      756 non-null    str
#  7   toss_decision    756 non-null    str
#  8   result           756 non-null    str
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    str
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    str
#  14  venue            756 non-null    str
#  15  umpire1          754 non-null    str
#  16  umpire2          754 non-null    str
#  17  umpire3          119 non-null    str
# ...

# %%
deliveries.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150460 entries, 0 to 150459
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          150460 non-null  int64
#  1   inning            150460 non-null  int64
#  2   batting_team      150460 non-null  str
#  3   bowling_team      150460 non-null  str
#  4   over              150460 non-null  int64
#  5   ball              150460 non-null  int64
#  6   batsman           150460 non-null  str
#  7   non_striker       150460 non-null  str
#  8   bowler            150460 non-null  str
#  9   is_super_over     150460 non-null  int64
#  10  wide_runs         150460 non-null  int64
#  11  bye_runs          150460 non-null  int64
#  12  legbye_runs       150460 non-null  int64
#  13  noball_runs       150460 non-null  int64
#  14  penalty_runs      150460 non-null  int64
#  15  batsman_runs      150460 non-null  int64
# ...

# %%
matches.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
deliveries.describe()
# Out:
#             match_id         inning           over           ball  \
# count  150460.000000  150460.000000  150460.000000  150460.000000
# mean      318.281317       1.482188      10.142649       3.616483
# std       182.955531       0.501768       5.674338       1.807698
# min         1.000000       1.000000       1.000000       1.000000
# 25%       161.000000       1.000000       5.000000       2.000000
# 50%       319.000000       1.000000      10.000000       4.000000
# 75%       476.000000       2.000000      15.000000       5.000000
# max       636.000000       4.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  150460.000000  150460.000000  150460.000000  150460.000000
# mean        0.000538       0.037498       0.004885       0.022232
# std         0.023196       0.257398       0.114234       0.200104
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
matches.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
deliveries.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    143022
# dismissal_kind      143022
# fielder             145091
# dtype: int64

# %%
matches['team1'].unique()
# Out:
# <ArrowStringArray>
# [        'Sunrisers Hyderabad',              'Mumbai Indians',
#                'Gujarat Lions',      'Rising Pune Supergiant',
#  'Royal Challengers Bangalore',       'Kolkata Knight Riders',
#             'Delhi Daredevils',             'Kings XI Punjab',
#          'Chennai Super Kings',            'Rajasthan Royals',
#              'Deccan Chargers',        'Kochi Tuskers Kerala',
#                'Pune Warriors',     'Rising Pune Supergiants',
#               'Delhi Capitals']
# Length: 15, dtype: str

# %%
wins = matches['winner'].value_counts()

plt.figure(figsize=(12,6))
sns.barplot(x=wins.index, y=wins.values)

plt.xticks(rotation=90)
plt.title("Most IPL Match Wins")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
matches = pd.read_csv("../data/matches.csv")
deliveries = pd.read_csv("../data/deliveries.csv")

# %%
matches.isnull().sum()
# Out:
# id                    0
# season                3
# city                 17
# date                  3
# team1                 3
# team2                 3
# toss_winner           3
# toss_decision         3
# result                3
# dl_applied            3
# winner               10
# win_by_runs           3
# win_by_wickets        3
# player_of_match      10
# venue                 3
# umpire1               6
# umpire2               6
# umpire3            1276
# dtype: int64

# %%
deliveries.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    143022
# dismissal_kind      143022
# fielder             145091
# dtype: int64

# %%
matches['city'] = matches['city'].fillna("Unknown")

# %%
matches = matches.dropna(subset=['winner'])

# %%
matches['team1'].unique()
# Out:
# <ArrowStringArray>
# [        'Sunrisers Hyderabad',              'Mumbai Indians',
#                'Gujarat Lions',      'Rising Pune Supergiant',
#  'Royal Challengers Bangalore',       'Kolkata Knight Riders',
#             'Delhi Daredevils',             'Kings XI Punjab',
#          'Chennai Super Kings',            'Rajasthan Royals',
#              'Deccan Chargers',        'Kochi Tuskers Kerala',
#                'Pune Warriors',     'Rising Pune Supergiants',
#               'Delhi Capitals']
# Length: 15, dtype: str

# %%
matches.replace(
    'Rising Pune Supergiants',
    'Rising Pune Supergiant',
    inplace=True
)
# Out:
#          id  season           city      date                        team1  \
# 1         1  2017.0      Hyderabad  5/4/2017          Sunrisers Hyderabad
# 2         2  2017.0           Pune  6/4/2017               Mumbai Indians
# 3         3  2017.0         Rajkot  7/4/2017                Gujarat Lions
# 4         4  2017.0         Indore  8/4/2017       Rising Pune Supergiant
# 5         5  2017.0      Bangalore  8/4/2017  Royal Challengers Bangalore
# ...     ...     ...            ...       ...                          ...
# 1389  11347  2019.0         Mumbai  05/05/19        Kolkata Knight Riders
# 1390  11412  2019.0        Chennai  07/05/19          Chennai Super Kings
# 1391  11413  2019.0  Visakhapatnam  08/05/19          Sunrisers Hyderabad
# 1392  11414  2019.0  Visakhapatnam  10/05/19               Delhi Capitals
# 1393  11415  2019.0      Hyderabad  12/05/19               Mumbai Indians
#
#                             team2                  toss_winner toss_decision  \
# ...

# %%
deliveries.replace(
    'Rising Pune Supergiants',
    'Rising Pune Supergiant',
    inplace=True
)
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
matches.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1385 entries, 1 to 1393
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1385 non-null   str
#  1   season           1385 non-null   float64
#  2   city             1385 non-null   str
#  3   date             1385 non-null   str
#  4   team1            1385 non-null   str
#  5   team2            1385 non-null   str
#  6   toss_winner      1385 non-null   str
#  7   toss_decision    1385 non-null   str
#  8   result           1385 non-null   str
#  9   dl_applied       1385 non-null   float64
#  10  winner           1385 non-null   str
#  11  win_by_runs      1385 non-null   float64
#  12  win_by_wickets   1385 non-null   float64
#  13  player_of_match  1385 non-null   str
#  14  venue            1385 non-null   str
#  15  umpire1          1382 non-null   str
#  16  umpire2          1382 non-null   str
#  17  umpire3          118 non-null    str
# ...

# %%
matches['date'] = pd.to_datetime(matches['date'], format='mixed')

# %%
deliveries['run_rate'] = deliveries['total_runs'] / deliveries['over']

# %%
matches['is_superover'] = np.where(
    matches['result'] == 'tie',
    1,
    0
)

# %%
matches['win_margin_normalized'] = (
    matches['win_by_runs'] +
    matches['win_by_wickets']
)

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3', 'is_superover', 'win_margin_normalized'],
#       dtype='str')

# %%
deliveries.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'run_rate'],
#       dtype='str')

# %%
deliveries['match_id'] = deliveries['match_id'].astype(int)
matches['id'] = matches['id'].astype(int)

# %%
ipl = deliveries.merge(
    matches,
    left_on='match_id',
    right_on='id',
    how='left'
)

# %%
ipl.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...
# 1     1  DA Warner    S Dhawan  TS Mills              0  ...
# 2     2  DA Warner    S Dhawan  TS Mills              0  ...
# 3     2  DA Warner    S Dhawan  TS Mills              0  ...
# 4     3  DA Warner    S Dhawan  TS Mills              0  ...
#
#                 winner  win_by_runs  win_by_wickets  player_of_match  \
# ...

# %%
ipl.shape
# Out:
# (300599, 42)

# %%
ipl.to_csv("../data/ipl_clean.csv", index=False)

# %%
plt.figure(figsize=(12,6))

matches['winner'].value_counts().head(10).plot(kind='bar')

plt.title("Top Winning IPL Teams")
plt.xlabel("Teams")
plt.ylabel("Wins")

plt.show()

# %%
sns.countplot(x='toss_decision', data=matches)

plt.title("Toss Decisions")
plt.show()

# %%
sns.countplot(x='is_superover', data=matches)

plt.title("Super Over Matches")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ipl = pd.read_csv("../data/ipl_clean.csv")

ipl.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...
# 1     1  DA Warner    S Dhawan  TS Mills              0  ...
# 2     2  DA Warner    S Dhawan  TS Mills              0  ...
# 3     2  DA Warner    S Dhawan  TS Mills              0  ...
# 4     3  DA Warner    S Dhawan  TS Mills              0  ...
#
#                 winner  win_by_runs  win_by_wickets  player_of_match  \
# ...

# %%
toss_match_win = (ipl['toss_winner'] == ipl['winner']).mean() * 100

print("Toss winner match win percentage:", toss_match_win)
# Out:
# Toss winner match win percentage: 50.99351627916261

# %%
labels = ['Won Match', 'Lost Match']
values = [toss_match_win, 100 - toss_match_win]

plt.figure(figsize=(6,5))
plt.bar(labels, values)

plt.title("Does Winning Toss Help?")
plt.ylabel("Percentage")

plt.show()

# %%
matches = pd.read_csv("../data/matches.csv")

# %%
bat_first = matches[matches['win_by_runs'] > 0]
chasing = matches[matches['win_by_wickets'] > 0]

print("Batting first wins:", len(bat_first))
print("Chasing wins:", len(chasing))
# Out:
# Batting first wins: 624
# Chasing wins: 745

# %%
plt.figure(figsize=(6,5))

sns.barplot(
    x=['Bat First', 'Chasing'],
    y=[len(bat_first), len(chasing)]
)

plt.title("Bat First vs Chasing Wins")

plt.show()

# %%
venue_runs = ipl.groupby('venue')['total_runs'].mean().sort_values(ascending=False).head(10)

venue_runs
# Out:
# venue
# Holkar Cricket Stadium                                  1.443223
# Brabourne Stadium                                       1.413019
# Green Park                                              1.409338
# Saurashtra Cricket Association Stadium                  1.399832
# Punjab Cricket Association IS Bindra Stadium, Mohali    1.377234
# M Chinnaswamy Stadium                                   1.354165
# Barabati Stadium                                        1.343953
# Himachal Pradesh Cricket Association Stadium            1.341825
# Punjab Cricket Association Stadium, Mohali              1.329180
# Maharashtra Cricket Association Stadium                 1.327202
# Name: total_runs, dtype: float64

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    x=venue_runs.index,
    y=venue_runs.values
)

plt.xticks(rotation=90)

plt.title("Highest Scoring IPL Venues")
plt.ylabel("Average Runs")

plt.show()

# %%
team_wins = matches['winner'].value_counts().head(10)

team_wins
# Out:
# winner
# Mumbai Indians                 201
# Chennai Super Kings            179
# Kolkata Knight Riders          169
# Royal Challengers Bangalore    157
# Kings XI Punjab                152
# Rajasthan Royals               138
# Delhi Daredevils               129
# Sunrisers Hyderabad            100
# Deccan Chargers                 58
# Gujarat Lions                   26
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    x=team_wins.index,
    y=team_wins.values
)

plt.xticks(rotation=90)

plt.title("Most Successful IPL Teams")
plt.ylabel("Wins")

plt.show()

# %%
corr = ipl[['total_runs', 'extra_runs', 'run_rate']].corr()

corr
# Out:
#             total_runs  extra_runs  run_rate
# total_runs    1.000000    0.078145  0.549228
# extra_runs    0.078145    1.000000  0.083333
# run_rate      0.549228    0.083333  1.000000

# %%
plt.figure(figsize=(6,5))

sns.heatmap(corr, annot=True)

plt.title("Feature Correlation Heatmap")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ipl = pd.read_csv("../data/ipl_clean.csv")

ipl.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...
# 1     1  DA Warner    S Dhawan  TS Mills              0  ...
# 2     2  DA Warner    S Dhawan  TS Mills              0  ...
# 3     2  DA Warner    S Dhawan  TS Mills              0  ...
# 4     3  DA Warner    S Dhawan  TS Mills              0  ...
#
#                 winner  win_by_runs  win_by_wickets  player_of_match  \
# ...

# %%
top_batsmen = (
    ipl.groupby('batsman')['batsman_runs']
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print(top_batsmen)
# Out:
# batsman
# SK Raina          9096
# V Kohli           8844
# RG Sharma         8414
# G Gambhir         8264
# DA Warner         8009
# RV Uthappa        7556
# CH Gayle          7291
# S Dhawan          7122
# MS Dhoni          7120
# AB de Villiers    6915
# Name: batsman_runs, dtype: int64

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    x=top_batsmen.index,
    y=top_batsmen.values
)

plt.xticks(rotation=45)

plt.title("Top 10 IPL Run Scorers")
plt.xlabel("Batsman")
plt.ylabel("Runs")

plt.show()

# %%
season_runs = (
    ipl.groupby(['season','batsman'])['batsman_runs']
    .sum()
    .reset_index()
)

top_season = season_runs.sort_values(
    ['season','batsman_runs'],
    ascending=[True,False]
).groupby('season').head(1)

top_season.head(10)
# Out:
#       season       batsman  batsman_runs
# 115   2008.0      SE Marsh          1232
# 229   2009.0     ML Hayden          1144
# 446   2010.0  SR Tendulkar          1236
# 502   2011.0      CH Gayle          1216
# 684   2012.0      CH Gayle          1466
# 910   2013.0    MEK Hussey          1466
# 1088  2014.0    RV Uthappa          1320
# 1148  2015.0     DA Warner          1124
# 1383  2016.0       V Kohli          1946
# 1422  2017.0     DA Warner          1282

# %%
death_overs = ipl[ipl['over'] >= 17]

death_overs.head()
# Out:
#      match_id  inning         batting_team                 bowling_team  over  \
# 198         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    17
# 199         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    17
# 200         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    17
# 201         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    17
# 202         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    17
#
#      ball       batsman   non_striker    bowler  is_super_over  ...  \
# 198     1      DJ Hooda  Yuvraj Singh  TS Mills              0  ...
# 199     1      DJ Hooda  Yuvraj Singh  TS Mills              0  ...
# 200     2  Yuvraj Singh      DJ Hooda  TS Mills              0  ...
# 201     2  Yuvraj Singh      DJ Hooda  TS Mills              0  ...
# 202     3  Yuvraj Singh      DJ Hooda  TS Mills              0  ...
#
#                   winner  win_by_runs  win_by_wickets  player_of_match  \
# ...

# %%
death_batsmen = (
    death_overs.groupby('batsman')['batsman_runs']
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print(death_batsmen)
# Out:
# batsman
# MS Dhoni          3418
# KA Pollard        2194
# RG Sharma         2080
# AB de Villiers    1810
# V Kohli           1448
# YK Pathan         1390
# JP Duminy         1368
# DJ Bravo          1216
# RA Jadeja         1190
# Yuvraj Singh      1188
# Name: batsman_runs, dtype: int64

# %%
balls_faced = (
    death_overs.groupby('batsman')
    .size()
)

runs_scored = (
    death_overs.groupby('batsman')['batsman_runs']
    .sum()
)

strike_rate = (
    (runs_scored / balls_faced) * 100
).sort_values(ascending=False)

strike_rate.head(10)
# Out:
# batsman
# PA Reddy          300.000000
# Misbah-ul-Haq     266.666667
# BJ Rohrer         235.483871
# Vishnu Vinod      233.333333
# LPC Silva         230.000000
# LJ Wright         225.000000
# YV Takawale       223.076923
# MA Agarwal        221.875000
# CR Brathwaite     221.428571
# AB de Villiers    221.271394
# dtype: float64

# %%
top_sr = strike_rate.head(10)

plt.figure(figsize=(12,6))

sns.barplot(
    x=top_sr.index,
    y=top_sr.values
)

plt.xticks(rotation=45)

plt.title("Best Death Over Strike Rates")
plt.ylabel("Strike Rate")

plt.show()

# %%
top_bowlers = (
    ipl['bowler']
    .value_counts()
    .head(10)
)

print(top_bowlers)
# Out:
# bowler
# Harbhajan Singh    5978
# A Mishra           5406
# SL Malinga         5388
# P Kumar            5274
# PP Chawla          5188
# R Ashwin           4718
# Z Khan             4551
# R Vinay Kumar      4322
# DW Steyn           4318
# IK Pathan          4226
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    x=top_bowlers.index,
    y=top_bowlers.values
)

plt.xticks(rotation=45)

plt.title("Top IPL Wicket Takers")

plt.show()

# %%
def phase(over):
    if over <= 6:
        return "Powerplay"
    elif over <= 15:
        return "Middle"
    else:
        return "Death"

ipl['phase'] = ipl['over'].apply(phase)

ipl[['over','phase']].head()
# Out:
#    over      phase
# 0     1  Powerplay
# 1     1  Powerplay
# 2     1  Powerplay
# 3     1  Powerplay
# 4     1  Powerplay

# %%
phase_runs = (
    ipl.groupby('phase')['total_runs']
    .mean()
)

print(phase_runs)
# Out:
# phase
# Death        1.547871
# Middle       1.226333
# Powerplay    1.204009
# Name: total_runs, dtype: float64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x=phase_runs.index,
    y=phase_runs.values
)

plt.title("Average Runs by Match Phase")

plt.ylabel("Average Runs")

plt.show()

# %%
innings_runs = (
    ipl.groupby(['match_id','batsman'])['batsman_runs']
    .sum()
    .reset_index()
)

thirty_plus = innings_runs[innings_runs['batsman_runs'] >= 30]

consistency = (
    thirty_plus['batsman']
    .value_counts()
    .head(10)
)

print(consistency)
# Out:
# batsman
# SK Raina          106
# V Kohli            93
# MS Dhoni           93
# RV Uthappa         91
# RG Sharma          91
# G Gambhir          88
# S Dhawan           82
# KD Karthik         75
# DA Warner          73
# AB de Villiers     72
# Name: count, dtype: int64

# %%
partnerships = (
    ipl.groupby(['batsman','non_striker'])['total_runs']
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print(partnerships)
# Out:
# batsman         non_striker
# CH Gayle        V Kohli           3223
# DA Warner       S Dhawan          2840
# V Kohli         CH Gayle          2369
# AB de Villiers  V Kohli           2222
# V Kohli         AB de Villiers    2193
# RV Uthappa      G Gambhir         2154
# S Dhawan        DA Warner         1874
# G Gambhir       RV Uthappa        1658
# DR Smith        BB McCullum       1476
# MEK Hussey      M Vijay           1424
# Name: total_runs, dtype: int64
